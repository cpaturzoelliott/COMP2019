# %% [markdown]
# <a href="https://colab.research.google.com/github/cpaturzoelliott/COMP2019/blob/main/COMP_2019_Week_1_Test_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # COMP 2019
# ## Week 1
# ### Test Notebook
# patcy025@mymail.unisa.edu.au

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
arr1 = np.array([3,5,4,6,3,2])
arr2 = np.array([4,3,7,5,3,1])
arr3 = arr1 + arr2
arr4 = (2*arr1) * (3*arr2)
print (arr3)
print(arr4)
# Out:
# [ 7  8 11 11  6  3]
# [ 72  90 168 180  54  12]

# %%
x = np.array([0, 1, 2, 3, 4, 5])
plt.figure()
plt.plot(x, arr1, color='green', marker='x')
plt.plot(x, arr2, color='red', marker='o')
plt.plot(x, arr3, color='blue', marker='+')

# %%
arr4 = np.array([[1,2,3],[4,5,6]])
arr5 = np.array([[7,8,9], [10, 11, 12], [13, 14, 15]])
arr6 = np.transpose(arr5)
print(arr6.shape)
print(arr6)
arr7 = np.matmul(arr5, arr6)
print (arr7)
# Out:
# (3, 3)
# [[ 7 10 13]
#  [ 8 11 14]
#  [ 9 12 15]]
# [[194 266 338]
#  [266 365 464]
#  [338 464 590]]
